# %%
from IPython import display
display.Image("./Figure_1.png")

# %%
# !nbdiff-web BOOKDIFF1.ipynb BOOKDIFF2.ipynb
# Out:
# [I nbdimeserver:422] Listening on 127.0.0.1, port 53094
# [I webutil:29] URL: http://127.0.0.1:53094/diff?base=BOOKDIFF1.ipynb&remote=BOOKDIFF2.ipynb
# [I nbdimeserver:315] Closing server on remote request

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random
#random.seed(15)

def randomf1():
    x=random.random()
    return x

sample = [randomf1() for i in range(1000)] # Get 1000 random variables
plt.figure(figsize=(16,8))
plt.hist(sample, bins=10, density=True, alpha=0.3)
plt.xlabel('Random value from U(0,1)')
plt.ylabel('Probability')
plt.show()

# %%
import random
num_list =  [7,8,10,12] 
print('list before using shuffle: ',num_list)
# Out:
# list before using shuffle:  [7, 8, 10, 12]

# %%
# !nbdiff-web BOOKDIFF1.ipynb BOOKDIFF2.ipynb
# Out:
# [I nbdimeserver:422] Listening on 127.0.0.1, port 57328
# [I webutil:29] URL: http://127.0.0.1:57328/diff?base=BOOKDIFF1.ipynb&remote=BOOKDIFF2.ipynb
# [I nbdimeserver:315] Closing server on remote request

# %%
num_list1 =  [7,10] 
print('list before using shuffle: ',num_list1)
